# %%
import Klubplywacki
import os
swim_files = os.listdir(Klubplywacki.FOLDER)
swim_files.remove(".DS_Store")

for n, i in enumerate(swim_files, 1):
    file = Klubplywacki.read_swim_data(i)
    swimmer, age, distance, stroke, times, average, converts = file
    print(f"{n} Przetwarzanie pliku: {i}")
    print(f"Plywak: {swimmer}\nWiek: {age}\nDystans: {distance}\nStyl:{stroke}\nCzasy: {times}\nSredni czas: {average}\n{converts}\n\n")
# Out:
# 1 Przetwarzanie pliku: Ala-12-100m-grzbietowy.txt
# Plywak: Ala
# Wiek: 12
# Dystans: 100m
# Styl:grzbietowy
# Czasy: ['1:36,54', '1:39,10', '1:39,45', '1:42,87']
# Sredni czas: 1:39,49
# [9654, 9910, 9945, 10287]
#
#
# 2 Przetwarzanie pliku: Ala-12-100m-kraul.txt
# Plywak: Ala
# Wiek: 12
# Dystans: 100m
# Styl:kraul
# Czasy: ['1:27,31', '1:27,00', '1:27,46', '1:22,50', '1:20,39', '1:26,04', '1:20,22']
# Sredni czas: 1:24,42
# [8731, 8700, 8746, 8250, 8039, 8604, 8022]
#
#
# 3 Przetwarzanie pliku: Alicja-14-100m-klasyczny.txt
# Plywak: Alicja
# Wiek: 14
# Dystans: 100m
# Styl:klasyczny
# Czasy: ['1:34,71', '1:37,87', '1:35,15', '1:37,20', '1:36,29', '1:36,00', '1:35,63', '1:35,42', '1:42,01']
# Sredni czas: 1:36,7
# [9471, 9787, 9515, 9720, 9629, 9600, 9563, 9542, 10201]
#
#
# 4 Przetwarzanie pliku: Alicja-14-100m-kraul.txt
# Plywak: Alicja
# Wiek: 14
# Dystans: 100m
# Styl:kraul
# Czasy: ['1:13,86', '1:12,00', '1:14,69', '1:10,01', '1:12,24', '1:11,00', '1:11,20', '1:12,28', '1:15,46', '1:16,03']
# Sredni czas: 1:12,88
# [7386, 7200, 7469, 7001, 7224, 7100, 7120, 7228, 7546, 7603]
#
#
# 5 Przetwarzanie pliku: Ania-10-100m-grzbietowy.txt
# Plywak: Ania
# Wiek: 10
# Dystans: 100m
# Styl:grzbietowy
# Czasy: ['1:31,59', '1:26,55', '1:28,75', '1:39,79', '1:32,37']
# Sredni czas: 1:31,81
# [9159, 8655, 8875, 9979, 9237]
#
#
# 6 Przetwarzanie pliku: Ania-10-100m-klasyczny.txt
# Plywak: Ania
# Wiek: 10
# Dystans: 100m
# Styl:klasyczny
# Czasy: ['1:42,97', '1:43,31', '1:43,50', '1:40,34']
# Sredni czas: 1:42,53
# [10297, 10331, 10350, 10034]
#
#
# 7 Przetwarzanie pliku: Ania-10-50m-grzbietowy.txt
# Plywak: Ania
# Wiek: 10
# Dystans: 50m
# Styl:grzbietowy
# Czasy: ['41,50', '43,58', '42,35', '43,35', '39,85', '40,53', '42,14', '39,18', '40,89', '40,89']
# Sredni czas: 0:41,43
# [4150, 4358, 4235, 4335, 3985, 4053, 4214, 3918, 4089, 4089]
#
#
# 8 Przetwarzanie pliku: Ania-10-50m-klasyczny.txt
# Plywak: Ania
# Wiek: 10
# Dystans: 50m
# Styl:klasyczny
# Czasy: ['48,08', '53,17', '45,76', '49,28', '52,85', '46,19', '47,76', '48,83', '45,71', '47,76']
# Sredni czas: 0:48,54
# [4808, 5317, 4576, 4928, 5285, 4619, 4776, 4883, 4571, 4776]
#
#
# 9 Przetwarzanie pliku: Ania-10-50m-kraul.txt
# Plywak: Ania
# Wiek: 10
# Dystans: 50m
# Styl:kraul
# Czasy: ['39,07', '37,66', '36,13', '39,42']
# Sredni czas: 0:38,07
# [3907, 3766, 3613, 3942]
#
#
# 10 Przetwarzanie pliku: Aurora-13-50m-kraul.txt
# Plywak: Aurora
# Wiek: 13
# Dystans: 50m
# Styl:kraul
# Czasy: ['30,05', '30,21', '28,86', '30,65', '30,03', '29,64', '29,82']
# Sredni czas: 0:29,89
# [3005, 3021, 2886, 3065, 3003, 2964, 2982]
#
#
# 11 Przetwarzanie pliku: Bartek-18-100m-grzbietowy.txt
# Plywak: Bartek
# Wiek: 18
# Dystans: 100m
# Styl:grzbietowy
# Czasy: ['1:11,34', '1:05,81', '1:05,75', '1:05,82']
# Sredni czas: 1:7,18
# [7134, 6581, 6575, 6582]
#
#
# 12 Przetwarzanie pliku: Bartek-18-200m-grzbietowy.txt
# Plywak: Bartek
# Wiek: 18
# Dystans: 200m
# Styl:grzbietowy
# Czasy: ['2:29,06', '2:21,49', '2:24,13', '2:29,40']
# Sredni czas: 2:26,02
# [14906, 14149, 14413, 14940]
#
#
# 13 Przetwarzanie pliku: Benek-15-100m-grzbietowy.txt
# Plywak: Benek
# Wiek: 15
# Dystans: 100m
# Styl:grzbietowy
# Czasy: ['1:12,71', '1:19,87', '1:14,94', '1:11,53', '1:14,94']
# Sredni czas: 1:14,8
# [7271, 7987, 7494, 7153, 7494]
#
#
# 14 Przetwarzanie pliku: Benek-15-100m-kraul.txt
# Plywak: Benek
# Wiek: 15
# Dystans: 100m
# Styl:kraul
# Czasy: ['1:02,13', '1:03,25', '1:04,16', '1:03,17', '1:04,84', '1:03,88', '1:04,87']
# Sredni czas: 1:3,76
# [6213, 6325, 6416, 6317, 6484, 6388, 6487]
#
#
# 15 Przetwarzanie pliku: Benek-15-100m-motyl.txt
# Plywak: Benek
# Wiek: 15
# Dystans: 100m
# Styl:motyl
# Czasy: ['1:11,49', '1:10,16', '1:12,59', '1:11,63', '1:09,43']
# Sredni czas: 1:11,06
# [7149, 7016, 7259, 7163, 6943]
#
#
# 16 Przetwarzanie pliku: Darek-13-100m-grzbietowy.txt
# Plywak: Darek
# Wiek: 13
# Dystans: 100m
# Styl:grzbietowy
# Czasy: ['1:22,57', '1:29,64', '1:20,39', '1:23,83']
# Sredni czas: 1:24,11
# [8257, 8964, 8039, 8383]
#
#
# 17 Przetwarzanie pliku: Darek-13-100m-klasyczny.txt
# Plywak: Darek
# Wiek: 13
# Dystans: 100m
# Styl:klasyczny
# Czasy: ['1:30,24', '1:33,18', '1:32,73', '1:33,05', '1:30,81', '1:31,74', '1:31,53', '1:33,05']
# Sredni czas: 1:32,04
# [9024, 9318, 9273, 9305, 9081, 9174, 9153, 9305]
#
#
# 18 Przetwarzanie pliku: Darek-13-100m-motyl.txt
# Plywak: Darek
# Wiek: 13
# Dystans: 100m
# Styl:motyl
# Czasy: ['1:27,95', '1:21,07', '1:30,96', '1:23,22', '1:27,95', '1:28,30']
# Sredni czas: 1:26,58
# [8795, 8107, 9096, 8322, 8795, 8830]
#
#
# 19 Przetwarzanie pliku: Darek-13-200m-zmienny.txt
# Plywak: Darek
# Wiek: 13
# Dystans: 200m
# Styl:zmienny
# Czasy: ['3:03,84', '3:04,27', '3:01,49', '3:04,27', '2:52,44']
# Sredni czas: 3:1,26
# [18384, 18427, 18149, 18427, 17244]
#
#
# 20 Przetwarzanie pliku: Dawid-17-100m-kraul.txt
# Plywak: Dawid
# Wiek: 17
# Dystans: 100m
# Styl:kraul
# Czasy: ['59,21', '59,27', '58,67', '59,72', '59,17']
# Sredni czas: 0:59,21
# [5921, 5927, 5867, 5972, 5917]
#
#
# 21 Przetwarzanie pliku: Dawid-17-200m-grzbietowy.txt
# Plywak: Dawid
# Wiek: 17
# Dystans: 200m
# Styl:grzbietowy
# Czasy: ['2:35,46', '2:28,30', '2:35,35', '2:28,84']
# Sredni czas: 2:31,99
# [15546, 14830, 15535, 14884]
#
#
# 22 Przetwarzanie pliku: Ela-14-100m-kraul.txt
# Plywak: Ela
# Wiek: 14
# Dystans: 100m
# Styl:kraul
# Czasy: ['1:06,01', '1:06,93', '1:05,34', '1:06,10']
# Sredni czas: 1:6,09
# [6601, 6693, 6534, 6610]
#
#
# 23 Przetwarzanie pliku: Eliza-14-100m-grzbietowy.txt
# Plywak: Eliza
# Wiek: 14
# Dystans: 100m
# Styl:grzbietowy
# Czasy: ['1:27,10', '1:26,21', '1:26,42', '1:35,79', '1:30,47']
# Sredni czas: 1:29,2
# [8710, 8621, 8642, 9579, 9047]
#
#
# 24 Przetwarzanie pliku: Eliza-14-100m-kraul.txt
# Plywak: Eliza
# Wiek: 14
# Dystans: 100m
# Styl:kraul
# Czasy: ['1:21,08', '1:11,23', '1:12,46', '1:16,73']
# Sredni czas: 1:15,38
# [8108, 7123, 7246, 7673]
#
#
# 25 Przetwarzanie pliku: Emma-13-100m-klasyczny.txt
# Plywak: Emma
# Wiek: 13
# Dystans: 100m
# Styl:klasyczny
# Czasy: ['2:01,15', '1:57,86', '1:59,38', '1:57,94', '1:56,97']
# Sredni czas: 1:58,66
# [12115, 11786, 11938, 11794, 11697]
#
#
# 26 Przetwarzanie pliku: Emma-13-100m-kraul.txt
# Plywak: Emma
# Wiek: 13
# Dystans: 100m
# Styl:kraul
# Czasy: ['1:32,21', '1:33,68', '1:34,10', '1:28,57']
# Sredni czas: 1:32,14
# [9221, 9368, 9410, 8857]
#
#
# 27 Przetwarzanie pliku: Eryka-15-100m-klasyczny.txt
# Plywak: Eryka
# Wiek: 15
# Dystans: 100m
# Styl:klasyczny
# Czasy: ['1:36,72', '1:34,78', '1:34,05', '1:32,78', '1:33,51', '1:33,29', '1:36,47', '1:31,82']
# Sredni czas: 1:34,18
# [9672, 9478, 9405, 9278, 9351, 9329, 9647, 9182]
#
#
# 28 Przetwarzanie pliku: Eryka-15-100m-kraul.txt
# Plywak: Eryka
# Wiek: 15
# Dystans: 100m
# Styl:kraul
# Czasy: ['1:19,04', '1:15,88', '1:18,62', '1:21,74']
# Sredni czas: 1:18,82
# [7904, 7588, 7862, 8174]
#
#
# 29 Przetwarzanie pliku: Eryka-15-200m-klasyczny.txt
# Plywak: Eryka
# Wiek: 15
# Dystans: 200m
# Styl:klasyczny
# Czasy: ['3:27,51', '3:34,70', '3:27,15', '3:28,45', '3:34,79', '3:30,21', '3:33,74']
# Sredni czas: 3:30,94
# [20751, 21470, 20715, 20845, 21479, 21021, 21374]
#
#
# 30 Przetwarzanie pliku: Hanna-13-100m-grzbietowy.txt
# Plywak: Hanna
# Wiek: 13
# Dystans: 100m
# Styl:grzbietowy
# Czasy: ['1:35,75', '1:32,78', '1:34,01', '1:32,57']
# Sredni czas: 1:33,78
# [9575, 9278, 9401, 9257]
#
#
# 31 Przetwarzanie pliku: Hanna-13-100m-kraul.txt
# Plywak: Hanna
# Wiek: 13
# Dystans: 100m
# Styl:kraul
# Czasy: ['1:21,43', '1:21,40', '1:21,62', '1:25,38']
# Sredni czas: 1:22,46
# [8143, 8140, 8162, 8538]
#
#
# 32 Przetwarzanie pliku: Karol-15-100m-grzbietowy.txt
# Plywak: Karol
# Wiek: 15
# Dystans: 100m
# Styl:grzbietowy
# Czasy: ['1:29,78', '1:28,38', '1:25,03', '1:25,66']
# Sredni czas: 1:27,21
# [8978, 8838, 8503, 8566]
#
#
# 33 Przetwarzanie pliku: Kasia-9-100m-grzbietowy.txt
# Plywak: Kasia
# Wiek: 9
# Dystans: 100m
# Styl:grzbietowy
# Czasy: ['1:33,36', '1:31,52', '1:28,10', '1:33,37', '1:32,89', '1:33,38', '1:32,03', '1:32,71']
# Sredni czas: 1:32,17
# [9336, 9152, 8810, 9337, 9289, 9338, 9203, 9271]
#
#
# 34 Przetwarzanie pliku: Kasia-9-100m-klasyczny.txt
# Plywak: Kasia
# Wiek: 9
# Dystans: 100m
# Styl:klasyczny
# Czasy: ['1:50,10', '1:47,12', '1:54,65', '1:51,03']
# Sredni czas: 1:50,72
# [11010, 10712, 11465, 11103]
#
#
# 35 Przetwarzanie pliku: Kasia-9-100m-kraul.txt
# Plywak: Kasia
# Wiek: 9
# Dystans: 100m
# Styl:kraul
# Czasy: ['1:20,81', '1:23,61', '1:24,80', '1:22,05', '1:22,58', '1:23,94']
# Sredni czas: 1:22,97
# [8081, 8361, 8480, 8205, 8258, 8394]
#
#
# 36 Przetwarzanie pliku: Kasia-9-50m-grzbietowy.txt
# Plywak: Kasia
# Wiek: 9
# Dystans: 50m
# Styl:grzbietowy
# Czasy: ['43,25', '47,35', '46,12', '45,69']
# Sredni czas: 0:45,6
# [4325, 4735, 4612, 4569]
#
#
# 37 Przetwarzanie pliku: Kasia-9-50m-klasyczny.txt
# Plywak: Kasia
# Wiek: 9
# Dystans: 50m
# Styl:klasyczny
# Czasy: ['47,44', '52,32', '57,16', '56,77']
# Sredni czas: 0:53,42
# [4744, 5232, 5716, 5677]
#
#
# 38 Przetwarzanie pliku: Kasia-9-50m-kraul.txt
# Plywak: Kasia
# Wiek: 9
# Dystans: 50m
# Styl:kraul
# Czasy: ['38,94', '37,76', '41,83', '42,81']
# Sredni czas: 0:40,34
# [3894, 3776, 4183, 4281]
#
#
# 39 Przetwarzanie pliku: Kasia-9-50m-motyl.txt
# Plywak: Kasia
# Wiek: 9
# Dystans: 50m
# Styl:motyl
# Czasy: ['40,11', '45,43', '50,17', '43,58', '52,61']
# Sredni czas: 0:46,38
# [4011, 4543, 5017, 4358, 5261]
#
#
# 40 Przetwarzanie pliku: Konrad-9-50m-grzbietowy.txt
# Plywak: Konrad
# Wiek: 9
# Dystans: 50m
# Styl:grzbietowy
# Czasy: ['38,79', '39,03', '41,29', '39,66', '41,13', '38,57', '39,40', '41,06', '40,37', '43,05', '37,85']
# Sredni czas: 0:40,02
# [3879, 3903, 4129, 3966, 4113, 3857, 3940, 4106, 4037, 4305, 3785]
#
#
# 41 Przetwarzanie pliku: Konrad-9-50m-kraul.txt
# Plywak: Konrad
# Wiek: 9
# Dystans: 50m
# Styl:kraul
# Czasy: ['35,78', '36,19', '36,89', '34,29', '34,18', '35,94']
# Sredni czas: 0:35,55
# [3578, 3619, 3689, 3429, 3418, 3594]
#
#
# 42 Przetwarzanie pliku: Konrad-9-50m-motyl.txt
# Plywak: Konrad
# Wiek: 9
# Dystans: 50m
# Styl:motyl
# Czasy: ['39,47', '37,30', '41,90', '42,85', '39,90', '38,66', '38,84', '37,65', '39,68', '37,18', '43,61']
# Sredni czas: 0:39,73
# [3947, 3730, 4190, 4285, 3990, 3866, 3884, 3765, 3968, 3718, 4361]
#
#
# 43 Przetwarzanie pliku: Krzysztof-17-100m-grzbietowy.txt
# Plywak: Krzysztof
# Wiek: 17
# Dystans: 100m
# Styl:grzbietowy
# Czasy: ['1:21,76', '1:23,32', '1:24,09', '1:21,51']
# Sredni czas: 1:22,67
# [8176, 8332, 8409, 8151]
#
#
# 44 Przetwarzanie pliku: Krzysztof-17-100m-klasyczny.txt
# Plywak: Krzysztof
# Wiek: 17
# Dystans: 100m
# Styl:klasyczny
# Czasy: ['1:28,86', '1:29,90', '1:28,12', '1:28,67']
# Sredni czas: 1:28,89
# [8886, 8990, 8812, 8867]
#
#
# 45 Przetwarzanie pliku: Maria-9-50m-kraul.txt
# Plywak: Maria
# Wiek: 9
# Dystans: 50m
# Styl:kraul
# Czasy: ['45,75', '41,62', '40,49', '41,00']
# Sredni czas: 0:42,22
# [4575, 4162, 4049, 4100]
#
#
# 46 Przetwarzanie pliku: Michal-15-100m-grzbietowy.txt
# Plywak: Michal
# Wiek: 15
# Dystans: 100m
# Styl:grzbietowy
# Czasy: ['1:19,23', '1:13,70', '1:13,96', '1:15,94']
# Sredni czas: 1:15,71
# [7923, 7370, 7396, 7594]
#
#
# 47 Przetwarzanie pliku: Michal-15-100m-kraul.txt
# Plywak: Michal
# Wiek: 15
# Dystans: 100m
# Styl:kraul
# Czasy: ['1:02,52', '1:02,56', '1:06,41', '1:07,08', '1:02,56', '1:03,23', '1:04,54']
# Sredni czas: 1:4,13
# [6252, 6256, 6641, 6708, 6256, 6323, 6454]
#
#
# 48 Przetwarzanie pliku: Michal-15-100m-motyl.txt
# Plywak: Michal
# Wiek: 15
# Dystans: 100m
# Styl:motyl
# Czasy: ['1:14,55', '1:14,15', '1:08,38', '1:08,74', '1:10,89', '1:09,47', '1:09,52', '1:09,86', '1:09,83']
# Sredni czas: 1:10,6
# [7455, 7415, 6838, 6874, 7089, 6947, 6952, 6986, 6983]
#
#
# 49 Przetwarzanie pliku: Michal-15-200m-kraul.txt
# Plywak: Michal
# Wiek: 15
# Dystans: 200m
# Styl:kraul
# Czasy: ['2:19,77', '2:41,57', '2:27,88', '2:37,28']
# Sredni czas: 2:31,62
# [13977, 16157, 14788, 15728]
#
#
# 50 Przetwarzanie pliku: Michal-15-200m-zmienny.txt
# Plywak: Michal
# Wiek: 15
# Dystans: 200m
# Styl:zmienny
# Czasy: ['2:48,05', '2:44,03', '2:38,93', '2:54,86']
# Sredni czas: 2:46,47
# [16805, 16403, 15893, 17486]
#
#
# 51 Przetwarzanie pliku: Olek-15-100m-kraul.txt
# Plywak: Olek
# Wiek: 15
# Dystans: 100m
# Styl:kraul
# Czasy: ['1:15,57', '1:14,40', '1:19,82', '1:12,90']
# Sredni czas: 1:15,67
# [7557, 7440, 7982, 7290]
#
#
# 52 Przetwarzanie pliku: Renia-13-100m-grzbietowy.txt
# Plywak: Renia
# Wiek: 13
# Dystans: 100m
# Styl:grzbietowy
# Czasy: ['1:17,16', '1:16,65', '1:23,11', '1:14,37', '1:18,16', '1:18,28', '1:16,87', '1:17,37', '1:20,46']
# Sredni czas: 1:18,05
# [7716, 7665, 8311, 7437, 7816, 7828, 7687, 7737, 8046]
#
#
# 53 Przetwarzanie pliku: Renia-13-100m-kraul.txt
# Plywak: Renia
# Wiek: 13
# Dystans: 100m
# Styl:kraul
# Czasy: ['1:07,99', '1:11,87', '1:11,08', '1:09,75']
# Sredni czas: 1:10,17
# [6799, 7187, 7108, 6975]
#
#
# 54 Przetwarzanie pliku: Renia-13-200m-grzbietowy.txt
# Plywak: Renia
# Wiek: 13
# Dystans: 200m
# Styl:grzbietowy
# Czasy: ['2:56,68', '2:42,63', '2:40,90', '2:42,88', '2:46,09']
# Sredni czas: 2:45,84
# [17668, 16263, 16090, 16288, 16609]
#
#
# 55 Przetwarzanie pliku: Renia-13-200m-kraul.txt
# Plywak: Renia
# Wiek: 13
# Dystans: 200m
# Styl:kraul
# Czasy: ['2:22,64', '2:28,16', '2:28,38', '2:25,08', '2:25,64', '2:33,58']
# Sredni czas: 2:27,25
# [14264, 14816, 14838, 14508, 14564, 15358]
#
#
# 56 Przetwarzanie pliku: Renia-13-400m-kraul.txt
# Plywak: Renia
# Wiek: 13
# Dystans: 400m
# Styl:kraul
# Czasy: ['5:11,32', '5:04,12', '5:20,67', '5:08,31', '5:04,32', '5:06,77', '5:13,01']
# Sredni czas: 5:9,79
# [31132, 30412, 32067, 30831, 30432, 30677, 31301]
#
#
# 57 Przetwarzanie pliku: Teresa-15-100m-grzbietowy.txt
# Plywak: Teresa
# Wiek: 15
# Dystans: 100m
# Styl:grzbietowy
# Czasy: ['1:19,63', '1:16,69', '1:19,68', '1:16,56']
# Sredni czas: 1:18,14
# [7963, 7669, 7968, 7656]
#
#
# 58 Przetwarzanie pliku: Teresa-15-100m-klasyczny.txt
# Plywak: Teresa
# Wiek: 15
# Dystans: 100m
# Styl:klasyczny
# Czasy: ['1:20,59', '1:26,48', '1:24,15', '1:21,96']
# Sredni czas: 1:23,3
# [8059, 8648, 8415, 8196]
#
#
# 59 Przetwarzanie pliku: Teresa-15-100m-kraul.txt
# Plywak: Teresa
# Wiek: 15
# Dystans: 100m
# Styl:kraul
# Czasy: ['1:08,87', '1:07,34', '1:11,00', '1:08,62', '1:10,94', '1:09,52', '1:12,04', '1:10,91']
# Sredni czas: 1:9,91
# [6887, 6734, 7100, 6862, 7094, 6952, 7204, 7091]
#
#
# 60 Przetwarzanie pliku: Teresa-15-200m-klasyczny.txt
# Plywak: Teresa
# Wiek: 15
# Dystans: 200m
# Styl:klasyczny
# Czasy: ['2:54,14', '3:03,58', '3:02,43', '2:57,99']
# Sredni czas: 2:59,53
# [17414, 18358, 18243, 17799]

# %%
#data = Klubplywacki.read_swim_data("Emma-13-100m-kraul.txt")
#times = data[4]
#swimmer, age, distance, style, times2, average = data
#print(f"Czasy: {times2}")
